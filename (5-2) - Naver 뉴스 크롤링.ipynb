# %%
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

'''''''''''''''''''''''''''''''''''''''''''''''''''''''''
< naver 뉴스 전문 가져오기 >_select 사용
- 네이버 뉴스만 가져와서 결과값 조금 작음 
- 결과 메모장 저장 -> 엑셀로 저장 

'''''''''''''''''''''''''''''''''''''''''''''''''''''''''
RESULT_PATH = r'C:\Users\Samsung\Desktop\news_sentiment'
now = datetime.now() #파일이름 현 시간으로 저장하기

def get_news(n_url):
    news_detail = []

    breq = requests.get(n_url)
    bsoup = BeautifulSoup(breq.content, 'html.parser')

    title = bsoup.select('h3#articleTitle')[0].text  #대괄호는  h3#articleTitle 인 것중 첫번째 그룹만 가져오겠다.
    news_detail.append(title)

    pdate = bsoup.select('.t11')[0].get_text()[:11]
    news_detail.append(pdate)

    _text = bsoup.select('#articleBodyContents')[0].get_text().replace('\n', " ")
    btext = _text.replace("// flash 오류를 우회하기 위한 함수 추가 function _flash_removeCallback() {}", "")
    news_detail.append(btext.strip())
  
    news_detail.append(n_url)
    
    pcompany = bsoup.select('#footer address')[0].a.get_text()
    news_detail.append(pcompany)

    return news_detail

def crawler(maxpage,query,s_date,e_date):

    s_from = s_date.replace(".","")
    e_to = e_date.replace(".","")
    page = 1
    maxpage_t =(int(maxpage)-1)*10+1   # 11= 2페이지 21=3페이지 31=4페이지  ...81=9페이지 , 91=10페이지, 101=11페이지
    f = open(r"C:\Users\Samsung\Desktop\news_sentiment\contents_text.txt", 'w', encoding='utf-8')
    
    while page < maxpage_t:
    
        print(page)
    
        url = "https://search.naver.com/search.naver?where=news&query=" + query + "&sort=0&ds=" + s_date + "&de=" + e_date + "&nso=so%3Ar%2Cp%3Afrom" + s_from + "to" + e_to + "%2Ca%3A&start=" + str(page)
        
        req = requests.get(url)
        print(url)
        cont = req.content
        soup = BeautifulSoup(cont, 'html.parser')
            #print(soup)
    
        for urls in soup.select("._sp_each_url"):
            try :
                #print(urls["href"])
                if urls["href"].startswith("https://news.naver.com"):
                    #print(urls["href"])
                    news_detail = get_news(urls["href"])
                        # pdate, pcompany, title, btext
                    f.write("{}\t{}\t{}\t{}\t{}\n".format(news_detail[1], news_detail[4], news_detail[0], news_detail[2],news_detail[3]))  # new style
            except Exception as e:
                print(e)
                continue
        page += 10
    
    
    f.close()
    
def excel_make():
    data = pd.read_csv(RESULT_PATH+'\contents_text.txt', sep='\t',header=None, error_bad_lines=False, encoding='utf-8')
    data.columns = ['years','company','title','contents','link']
    print(data)
    
    xlsx_outputFileName = '%s-%s-%s  %s시 %s분 %s초 result.xlsx' % (now.year, now.month, now.day, now.hour, now.minute, now.second)
    #xlsx_name = 'result' + '.xlsx'
    data.to_excel(RESULT_PATH+xlsx_outputFileName, encoding='utf-8')


def main():
    maxpage = input("최대 출력할 페이지수 입력하시오: ") 
    query = input("검색어 입력: ")
    s_date = input("시작날짜 입력(2019.01.01):")  #2019.01.01
    e_date = input("끝날짜 입력(2019.04.28):")   #2019.04.28
    crawler(maxpage,query,s_date,e_date) #검색된 네이버뉴스의 기사내용을 크롤링합니다. 
    
    excel_make() #엑셀로 만들기 
main()

excel_make()
# Out:
# 최대 출력할 페이지수 입력하시오: 10
# 검색어 입력: 엘지
# 시작날짜 입력(2019.01.01):2020.08.01
# 끝날짜 입력(2019.04.28):2020.08.10
# 1
# https://search.naver.com/search.naver?where=news&query=엘지&sort=0&ds=2020.08.01&de=2020.08.10&nso=so%3Ar%2Cp%3Afrom20200801to20200810%2Ca%3A&start=1
# 11
# https://search.naver.com/search.naver?where=news&query=엘지&sort=0&ds=2020.08.01&de=2020.08.10&nso=so%3Ar%2Cp%3Afrom20200801to20200810%2Ca%3A&start=11
# 21
# https://search.naver.com/search.naver?where=news&query=엘지&sort=0&ds=2020.08.01&de=2020.08.10&nso=so%3Ar%2Cp%3Afrom20200801to20200810%2Ca%3A&start=21
# 31
# https://search.naver.com/search.naver?where=news&query=엘지&sort=0&ds=2020.08.01&de=2020.08.10&nso=so%3Ar%2Cp%3Afrom20200801to20200810%2Ca%3A&start=31
# list index out of range
# 41
# https://search.naver.com/search.naver?where=news&query=엘지&sort=0&ds=2020.08.01&de=2020.08.10&nso=so%3Ar%2Cp%3Afrom20200801to20200810%2Ca%3A&start=41
# 51
# https://search.naver.com/search.naver?where=news&query=엘지&sort=0&ds=2020.08.01&de=2020.08.10&nso=so%3Ar%2Cp%3Afrom20200801to20200810%2Ca%3A&start=51
# 61
# https://search.naver.com/search.naver?where=news&query=엘지&sort=0&ds=2020.08.01&de=2020.08.10&nso=so%3Ar%2Cp%3Afrom20200801to20200810%2Ca%3A&start=61
# 71
# https://search.naver.com/search.naver?where=news&query=엘지&sort=0&ds=2020.08.01&de=2020.08.10&nso=so%3Ar%2Cp%3Afrom20200801to20200810%2Ca%3A&start=71
# 81
# https://search.naver.com/search.naver?where=news&query=엘지&sort=0&ds=2020.08.01&de=2020.08.10&nso=so%3Ar%2Cp%3Afrom20200801to20200810%2Ca%3A&start=81
#           years                     company  \
# 0   2020.08.09.      The Internet Hankyoreh
# 1   2020.08.09.      The Internet Hankyoreh
# 2   2020.08.10.                       헤럴드경제
# 3   2020.08.04.      The Internet Hankyoreh
# 4   2020.08.02.      The Internet Hankyoreh
# 5   2020.08.07.      The Internet Hankyoreh
# 6   2020.08.03.      The Internet Hankyoreh
# 7   2020.08.02.      The Internet Hankyoreh
# 8   2020.08.09.      The Internet Hankyoreh
# 9   2020.08.07.      The Internet Hankyoreh
# 10  2020.08.07.                         KBS
# 11  2020.08.10.                       헤럴드경제
# 12  2020.08.10.                     아시아경제신문
# 13  2020.08.09.                        서울경제
# 14  2020.08.07.      The Internet Hankyoreh
# 15  2020.08.04.      The Internet Hankyoreh
# 16  2020.08.07.      The Internet Hankyoreh
# 17  2020.08.03.                 ZDNet Korea
# 18  2020.08.05.                        문화일보
# 19  2020.08.04.                         뉴스1
# 20  2020.08.04.                        JTBC
# 21  2020.08.07.                  MoneyToday
# 22  2020.08.03.                       헤럴드경제
# 23  2020.08.03.  코메디닷컴 All Rights Reserved.
# 24  2020.08.05.                  MoneyToday
# 25  2020.08.03.                  MoneyToday
# 26  2020.08.04.                         머니S
# 27  2020.08.04.                         머니S
# 28  2020.08.04.                         머니S
# 29  2020.08.04.                         머니S
#
#                                                title  \
# 0                           엘지전자, 호텔서 요리 배송로봇 시범 서비스
# 1                  ‘설비투자 4조 목표’ 못 미친 통신3사…KT가 약속 어겼다
# 2         [리더스칼럼-권경인 에릭슨엘지 최고기술책임자(CTO)] 제조업의 부활과 5G
# 3                 쓰던 TV 반납하고 LG 올레드 구매하면 최대 200만원 혜택
# 4         아직 ‘골드스타 전자레인지’ 쓴다고?…“디오스 주방가전 3총사로 바꿔드려요”
# 5                 LG화학-CATL 양강 체제…‘전기차 배터리 2파전’ 막올랐다
# 6                          ESS 화재 책임 놓고 미국서도 공방 ‘활활’
# 7                       LG전자 건강관리 가전 매출 3년 새 2.5배 껑충
# 8                삼성·현대차·SK·LG·현대중, 수해복구 성금 10~30억 전달
# 9                   아시아나항공도 ‘화물 덕분에’…2분기 영업이익 1151억원
# 10                         11일부터 프로스포츠 관중 입장 30%로 확대
# 28  https://news.naver.com/main/read.nhn?mode=LSD&...
# 29  https://news.naver.com/main/read.nhn?mode=LSD&...
#           years                     company  \
# 0   2020.08.09.      The Internet Hankyoreh
# 1   2020.08.09.      The Internet Hankyoreh
# 2   2020.08.10.                       헤럴드경제
# 3   2020.08.04.      The Internet Hankyoreh
# 4   2020.08.02.      The Internet Hankyoreh
# 5   2020.08.07.      The Internet Hankyoreh
# 6   2020.08.03.      The Internet Hankyoreh
# 7   2020.08.02.      The Internet Hankyoreh
# 8   2020.08.09.      The Internet Hankyoreh
# 9   2020.08.07.      The Internet Hankyoreh
# 10  2020.08.07.                         KBS
# 11  2020.08.10.                       헤럴드경제
# 12  2020.08.10.                     아시아경제신문
# 13  2020.08.09.                        서울경제
# 14  2020.08.07.      The Internet Hankyoreh
# 15  2020.08.04.      The Internet Hankyoreh
# 16  2020.08.07.      The Internet Hankyoreh
# 17  2020.08.03.                 ZDNet Korea
# 18  2020.08.05.                        문화일보
# 19  2020.08.04.                         뉴스1
# 20  2020.08.04.                        JTBC
# 21  2020.08.07.                  MoneyToday
# 22  2020.08.03.                       헤럴드경제
# 23  2020.08.03.  코메디닷컴 All Rights Reserved.
# 24  2020.08.05.                  MoneyToday
# 25  2020.08.03.                  MoneyToday
# 26  2020.08.04.                         머니S
# 27  2020.08.04.                         머니S
# 28  2020.08.04.                         머니S
# 29  2020.08.04.                         머니S
#
#                                                title  \
# 0                           엘지전자, 호텔서 요리 배송로봇 시범 서비스
# 1                  ‘설비투자 4조 목표’ 못 미친 통신3사…KT가 약속 어겼다
# 2         [리더스칼럼-권경인 에릭슨엘지 최고기술책임자(CTO)] 제조업의 부활과 5G
# 3                 쓰던 TV 반납하고 LG 올레드 구매하면 최대 200만원 혜택
# 4         아직 ‘골드스타 전자레인지’ 쓴다고?…“디오스 주방가전 3총사로 바꿔드려요”
# 5                 LG화학-CATL 양강 체제…‘전기차 배터리 2파전’ 막올랐다
# 6                          ESS 화재 책임 놓고 미국서도 공방 ‘활활’
# 7                       LG전자 건강관리 가전 매출 3년 새 2.5배 껑충
# 8                삼성·현대차·SK·LG·현대중, 수해복구 성금 10~30억 전달
# 9                   아시아나항공도 ‘화물 덕분에’…2분기 영업이익 1151억원
# 10                         11일부터 프로스포츠 관중 입장 30%로 확대
# 11  전참시 등장한 유병재 반려동물 전용CCTV에 ‘팸펫족’ 시선집중…유플러스펫케어 ‘맘카’
# 12          전참시 유병재의 반려동물 전용CCTV는? 유플러스펫케어 ‘맘카’로 알려져
# 13    전참시 방송에서 유병재가 사용했던 반려동물 전용CCTV 유플러스펫케어 ‘맘카’ 화제
# 14                       중기부, 특별재난지역 중소기업·소상공인 지원 나서
# 15             “‘한국판 뉴딜’은 기회의 문”…재계 순위 11~20위권 격변 예상
# 16                   ‘물만난’ 가전 3총사…의류건조기·의류관리기·제습기 특수
# 17                        토스페이먼츠, 이커머스 간편결제 경쟁구도 만들까
# 18                <복직편살>닦아도 닦아도 입냄새… 부장님, 치약은 죄가 없어요
# 19                  LG전자, 디자인경영센터 신입사원 채용…온라인 면접·인턴십
# 20               역대급 무더위라더니…최장 장마에 에어컨 판매 '뚝'｜아침& 지금
# 21                                     [장외주식] 솔루엠 강세
# 22                  여수 LG화학, 저소득층 어르신들에 눈꺼풀 처짐 수술 후원
# 23              동아제약 등 5개 기업, 지난해 의약외품 생산실적 55.5% 차지
# 24                                 [장외주식] 현대엠엔소프트 강세
# 25                                    [장외주식] 솔루엠 상승세
# 26                     [주목! 경매물건] 일산동 59.9㎡ 1.4억에 시작
# 27                     [주목! 경매물건] 일산동 59.9㎡ 1.4억에 시작
# 28                     [주목! 경매물건] 일산동 59.9㎡ 1.4억에 시작
# 29                     [주목! 경매물건] 일산동 59.9㎡ 1.4억에 시작
#
#                                              contents  \
# 0   엘지 계열사, 로봇·자율주행 분야 적극 진출로봇 활용 식당에 무인배송, 공장에 무인...
# 1   상반기 투자 3조4400억 그쳐 SKT 작년보다 27% 늘렸는데 KT 28.6% 줄...
# 2   제조업은 국가 산업의 중추다. 제조업이 강한 국가는 위기에 강하다. 2017년 기준...
# 3   LG전자, TV 보상판매 실시LG전자가 기존에 사용한 LED·LCD TV 등 구형 ...
# 4   LG전자 고객 SNS 이벤트 진행LG전자가 8월3일부터 9월6일까지 가장 오래된 골...
# 5   LG화학 올해 세계 1위 올라중 CATL 점유율 차이는 미미테슬라 모델3 스탠다드 ...
# 6   미국 애리조나주 작년 4월 사고전력회사 APS “배터리 내부결함”LG화학 “외부충격...
# 7   LG전자, ‘2019-2020 지속가능 경영보고서’ 발행연말 쇼핑 시즌을 맞아 멕시...
# 8   수해 버티지 못하고 기울어진 나무 =호우경보가 발효된 9일 오전 한강 수위가 상승하...
# 9   6분기만에 흑자 전환“전년동기 대비 화물부문 매출 95% 증가”아시아나항공 제공아시...
# 10  문화체육관광부가 방역 당국과 협의를 거쳐 오는 11일(화) 프로야구 경기부터 관중석...
# 11  [헤럴드경제] MBC 인기 예능 프로그램 전시적참견시점(이하 전참시)에서 방송인 유...
# 12  MBC 인기 예능 프로그램 전시적참견시점(이하 전참시)에 출연 중인 방송인 유병재가...
# 13  [서울경제] MBC 인기 예능 프로그램 전시적참견시점(이하 전참시)에서 방송인 유병...
# 14  중소기업·소상공인 특례보증비율·보증 한도 상향피해 중소기업에 10억원 이내 1.9%...
# 15  40대 그룹 전략담당 임원들 평가와 전망도약이냐 추락이냐 긴장감 커유통그룹, 정보인...
# 16  1주일새 하이마트서 50% 더 팔려 의류관리기는 작년보다 110% 증가 건강관리 수...
# 17  토스 간편결제 9월 중 토스페이먼츠에 내재화(지디넷코리아=손예술  기자)모바일 금융...
# 18  - 입냄새 왜 날까 ① 당뇨·신장질환 등 병적구취  ② 노화·공복 인한 생리적구취 ...
# 19  개인 디자인으로 서류전형 대체LG전자 여의도 사옥© News1(서울=뉴스1) 정상훈...
# 20  동영상 뉴스       [앵커]이게 참 앞날을 알 수가 없는게요. 원래는 이번 여름...
# 21  [머니투데이 피스탁  ]  7일 코스피시장(2351.67pt)은 기관과 외국인은 매...
# 22  [헤럴드경제(여수)=박대성 기자] LG화학 여수공장(주재임원 윤명훈 전무)은 어려운...
# 23  [표= 2019년 국내 의약외품 생산실적 상위 5개 업체]지난해 국내 의약외품 생산...
# 24  [머니투데이 피스탁  ]  5일 코스피시장(2311.86pt)은 기관과 외국인은 매...
# 25  [머니투데이 피스탁  ]  3일 코스피시장(2251.04pt)은 기관과 외국인은 매...
# 26  ◆수원 금곡동 아파트 99.9㎡, 1회 유찰 2억4990만원경기 수원 권선구 금곡동...
# 27  ◆수원 금곡동 아파트 99.9㎡, 1회 유찰 2억4990만원경기 수원 권선구 금곡동...
# 28  ◆수원 금곡동 아파트 99.9㎡, 1회 유찰 2억4990만원경기 수원 권선구 금곡동...
# 29  ◆수원 금곡동 아파트 99.9㎡, 1회 유찰 2억4990만원경기 수원 권선구 금곡동...
#
#                                                  link
# 0   https://news.naver.com/main/read.nhn?mode=LSD&...
# 1   https://news.naver.com/main/read.nhn?mode=LSD&...
# 2   https://news.naver.com/main/read.nhn?mode=LSD&...
# 3   https://news.naver.com/main/read.nhn?mode=LSD&...
# 4   https://news.naver.com/main/read.nhn?mode=LSD&...
# 5   https://news.naver.com/main/read.nhn?mode=LSD&...
# 6   https://news.naver.com/main/read.nhn?mode=LSD&...
# 7   https://news.naver.com/main/read.nhn?mode=LSD&...
# 8   https://news.naver.com/main/read.nhn?mode=LSD&...
# 9   https://news.naver.com/main/read.nhn?mode=LSD&...
# 10  https://news.naver.com/main/read.nhn?mode=LSD&...
# 11  https://news.naver.com/main/read.nhn?mode=LSD&...
# 12  https://news.naver.com/main/read.nhn?mode=LSD&...
# 13  https://news.naver.com/main/read.nhn?mode=LSD&...
# 14  https://news.naver.com/main/read.nhn?mode=LSD&...
# 15  https://news.naver.com/main/read.nhn?mode=LSD&...
# 16  https://news.naver.com/main/read.nhn?mode=LSD&...
# 17  https://news.naver.com/main/read.nhn?mode=LSD&...
# 18  https://news.naver.com/main/read.nhn?mode=LSD&...
# 19  https://news.naver.com/main/read.nhn?mode=LSD&...
# 20  https://news.naver.com/main/read.nhn?mode=LSD&...
# 21  https://news.naver.com/main/read.nhn?mode=LSD&...
# 22  https://news.naver.com/main/read.nhn?mode=LSD&...
# 23  https://news.naver.com/main/read.nhn?mode=LSD&...
# 24  https://news.naver.com/main/read.nhn?mode=LSD&...
# 25  https://news.naver.com/main/read.nhn?mode=LSD&...
# 26  https://news.naver.com/main/read.nhn?mode=LSD&...
# 27  https://news.naver.com/main/read.nhn?mode=LSD&...
# 28  https://news.naver.com/main/read.nhn?mode=LSD&...
# 29  https://news.naver.com/main/read.nhn?mode=LSD&...
# b'Skipping line 8: expected 5 fields, saw 7\nSkipping line 9: expected 5 fields, saw 7\nSkipping line 10: expected 5 fields, saw 7\n'
# b'Skipping line 8: expected 5 fields, saw 7\nSkipping line 9: expected 5 fields, saw 7\nSkipping line 10: expected 5 fields, saw 7\n'
